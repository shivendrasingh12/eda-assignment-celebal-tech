# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('country_stats_1993_appendix2_csv.csv')

# %%
#1 understanding the data

# %%
data.head()
# Out:
#                country  number of incidents percent  number killed  \
# 0          afghanistan                   20   0.40%             65
# 1              albania                    2   0.04%              0
# 2              algeria                  311   6.28%            602
# 3               angola                   34   0.69%            373
# 4  antigua and barbuda                    1   0.02%              0
#
#    number injured  number us killed  number us injured
# 0              50                 0                  1
# 1               2                 0                  0
# 2             126                 0                  0
# 3             111                 0                  0
# 4               0                 0                  0

# %%
data.tail()
# Out:
#         country  number of incidents percent  number killed  number injured  \
# 122   venezuela                   49   0.99%              2              13
# 123     vietnam                    2   0.04%              0               1
# 124       yemen                   23   0.46%             12               7
# 125  yugoslavia                    5   0.10%              1               5
# 126      zambia                    1   0.02%              0               0
#
#      number us killed  number us injured
# 122                 0                  0
# 123                 0                  0
# 124                 0                  2
# 125                 0                  0
# 126                 0                  0

# %%
data.shape
# Out:
# (127, 7)

# %%
data.describe()
# Out:
#        number of incidents  number killed  number injured  number us killed  \
# count           127.000000     127.000000      127.000000        127.000000
# mean             39.007874      80.015748       95.874016          0.354331
# std              78.069413     218.541049      281.409688          2.644334
# min               1.000000       0.000000        0.000000          0.000000
# 25%               3.000000       0.000000        0.000000          0.000000
# 50%               7.000000       3.000000        5.000000          0.000000
# 75%              31.000000      41.500000       50.000000          0.000000
# max             426.000000    1268.000000     2546.000000         28.000000
#
#        number us injured
# count         127.000000
# mean            9.559055
# std            93.528678
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max          1048.000000

# %%
data.columns
# Out:
# Index(['country', 'number of incidents', 'percent', 'number killed',
#        'number injured', 'number us killed', 'number us injured'],
#       dtype='object')

# %%
data.nunique()
# Out:
# country                127
# number of incidents     52
# percent                 52
# number killed           53
# number injured          55
# number us killed         5
# number us injured        7
# dtype: int64

# %%
data['number killed'].unique()
# Out:
# array([  65,    0,  602,  373,    2,    5,   16,   40,    7,   97,  106,
#         279,   10,  233,   13,  256,    4,    1,  132,   32,  194,   27,
#          12,   36, 1219,   78,   33,  142,   14,   15,   53,   51,   47,
#           3,  147,   87,    6,   73,  228,   43,  316,  346,  203,   81,
#         121,   30,  115, 1009,   19, 1268,   34, 1166,   21], dtype=int64)

# %%
#cleaning the data

# %%
data.isnull().sum()
# Out:
# country                0
# number of incidents    0
# percent                0
# number killed          0
# number injured         0
# number us killed       0
# number us injured      0
# dtype: int64

# %%
terror=data.drop(['number us killed','number us injured'],axis=1)

# %%
terror.head()
# Out:
#                country  number of incidents percent  number killed  \
# 0          afghanistan                   20   0.40%             65
# 1              albania                    2   0.04%              0
# 2              algeria                  311   6.28%            602
# 3               angola                   34   0.69%            373
# 4  antigua and barbuda                    1   0.02%              0
#
#    number injured
# 0              50
# 1               2
# 2             126
# 3             111
# 4               0

# %%
#3 relationship analysis

# %%
corelation=terror.corr()

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(terror)

# %%
sns.relplot(x='number injured',y='number killed',hue='country',data=terror)

# %%
sns.distplot(terror['number of incidents'])
# Out:
# C:\Users\KIIT\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='number of incidents', ylabel='Density'>

# %%
pip install jupyterthemes
# Out:
# ...
#      ---------------------------------------- 7.0/7.0 MB 2.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 46.7/46.7 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 49.6/49.6 kB 2.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
jt -t <onedork>
# Out:
#   File "C:\Users\KIIT\AppData\Local\Temp\ipykernel_21588\3120831067.py", line 1
#     jt -t <onedork>
#                    ^
# SyntaxError: invalid syntax
